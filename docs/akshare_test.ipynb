# %% [markdown]
# # openbb_akshare
#
# Version: 0.4.12

# %%
import pandas as pd

def get_df(obj) -> pd.DataFrame:
    d = [item.model_dump() for item in obj.results]
    return pd.DataFrame(d)

# %% [markdown]
# ## Caching `openbb_akshare` data
#
# There are query limitations on the number of requests that can be made to the akshare API. We need to cache the data to avoid hitting these limits.
#
# References:
# - https://github.com/ranaroussi/yfinance/blob/main/yfinance/cache.py
# - https://github.com/ValueRaider/yfinance-cache

# %%
from openbb_core.app.constants import USER_SETTINGS_PATH
from openbb_core.app.model.defaults import Defaults
from openbb_core.app.model.preferences import Preferences
from openbb_core.app.model.profile import Profile

from openbb import obb
# Data can be cached in the OpenBB user preferences directory.
# obb.user.preferences.data_directory
# obb.user.preferences.cache_directory
# obb.user.preferences.export_directory

# %%
from openbb_core.app.utils import get_user_cache_directory
get_user_cache_directory()
# Out:
# 'C:\\Users\\Roger\\OpenBBUserData\\cache'

# %% [markdown]
# ## Implementation

# %% [markdown]
# #### Currency
# ##### CurrencyHistorical
#
# AKShare API: https://akshare.akfamily.xyz/data/fx/fx.html#id2
#
# 东财数据 ： https://quote.eastmoney.com/cnyrate/EURCNYC.html

# %%
from openbb import obb
h_obj = obb.currency.price.historical(symbol='EURUSD', provider='akshare')

# %%
currency_data = get_df(h_obj)
currency_data.head()
# Out:
#          date   open   high    low  close volume  vwap  change  symbol   name
# 0  1999-01-01  1.174  1.180  1.166  1.180   None  None    0.00  EURUSD  欧元兑美元
# 1  1999-01-04  1.175  1.190  1.174  1.179   None  None    1.36  EURUSD  欧元兑美元
# 2  1999-01-05  1.179  1.184  1.177  1.182   None  None    0.59  EURUSD  欧元兑美元
# 3  1999-01-06  1.182  1.182  1.172  1.175   None  None    0.85  EURUSD  欧元兑美元
# 4  1999-01-07  1.175  1.177  1.156  1.166   None  None    1.79  EURUSD  欧元兑美元

# %%
import akshare as ak

forex_hist_em_df = ak.forex_hist_em(symbol="USDCNH")
#forex_hist_em_df.to_excel("docs/forex_hist_em.xlsx")

# %%
#forex_hist_em_df[["日期", "今开", "最高", "最低"]].head()
forex_hist_em_df.head()
# Out:
#            日期      代码        名称      今开     最新价      最高      最低    振幅
# 0  2010-08-23  USDCNH  美元兑离岸人民币  6.7200  6.7250  6.7250  6.7200  0.00
# 1  2010-08-24  USDCNH  美元兑离岸人民币  6.7230  6.7265  6.7265  6.7230  0.05
# 2  2010-08-25  USDCNH  美元兑离岸人民币  6.7325  6.7325  6.7325  6.7325  0.00
# 3  2010-08-26  USDCNH  美元兑离岸人民币  6.7500  6.7450  6.7500  6.7450  0.07
# 4  2010-08-27  USDCNH  美元兑离岸人民币  6.7530  6.7530  6.7530  6.7530  0.00

# %% [markdown]
# ##### CurrencySnapshots
#
# AKShare API: https://akshare.akfamily.xyz/data/fx/fx.html#id1
#
# 东财数据: https://quote.eastmoney.com/center/gridlist.html#forex_all

# %%
from openbb import obb
s_obj = obb.currency.snapshots(provider='akshare')

# %%
snapshot_data = get_df(s_obj)
snapshot_data.head()
# Out:
#   base_currency counter_currency  last_rate       open       high        low  \
# 0        USDARS         美元兑阿根廷比索  1231.4321  1241.6196  1244.2923  1231.0077
# 1       CNYKRWC         人民币韩元中间价   190.6100   190.6100   190.6100   190.6100
# 2        JPYZAR       100日元兑南非兰特    12.0828    12.1649    12.2157    12.0753
# 3        CHFZAR          瑞郎兑南非兰特    22.0152    22.1649    22.2293    21.9719
# 4        EURZAR          欧元兑南非兰特    20.5805    20.7203    20.7747    20.5799
#
#   close volume  prev_close   change  change_percent
# 0  None   None   1231.5053  10.1143          0.0082
# 1  None   None    189.3600   1.2500          0.0066
# 2  None   None     12.0901   0.0748          0.0062
# 3  None   None     22.0297   0.1352          0.0061
# 4  None   None     20.5999   0.1204          0.0058

# %%
import akshare as ak

forex_spot_em_df = ak.forex_spot_em()
#forex_spot_em_df.to_excel("docs/forex_spot_em.xlsx")

# %%
new_df=forex_spot_em_df.drop(columns=["序号"])
new_df.head()
# Out:
#         代码          名称        最新价      涨跌额   涨跌幅         今开         最高  \
# 0   USDARS    美元兑阿根廷比索  1231.4321  10.1143  0.82  1241.6196  1244.2923
# 1  CNYKRWC    人民币韩元中间价   190.6100   1.2500  0.66   190.6100   190.6100
# 2   JPYZAR  100日元兑南非兰特    12.0828   0.0748  0.62    12.1649    12.2157
# 3   CHFZAR     瑞郎兑南非兰特    22.0152   0.1352  0.61    22.1649    22.2293
# 4   EURZAR     欧元兑南非兰特    20.5805   0.1204  0.58    20.7203    20.7747
#
#           最低         昨收
# 0  1231.0077  1231.5053
# 1   190.6100   189.3600
# 2    12.0753    12.0901
# 3    21.9719    22.0297
# 4    20.5799    20.5999

# %% [markdown]
# #### CashFlowStatement

# %% [markdown]
# ##### 现金流量表-东财 按年度
#
# AKShare API: https://akshare.akfamily.xyz/data/stock/stock.html#id188
#
# 东财数据: https://emweb.securities.eastmoney.com/PC_HSF10/NewFinanceAnalysis/Index?type=web&code=sh600519#lrb-0

# %%
from openbb import obb
cash_obj = obb.equity.fundamental.cash(symbol="600028", provider="akshare")
cash_flow = get_df(cash_obj)
cash_flow.head()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   period_ending fiscal_period fiscal_year reported_currency  \
# 0    2024-12-31            年报        None               CNY
# 1    2023-12-31            年报        None               CNY
# 2    2022-12-31            年报        None               CNY
# 3    2021-12-31            年报        None               CNY
# 4    2020-12-31            年报        None               CNY
#
#    TOTAL_OPERATE_INFLOW  TOTAL_OPERATE_OUTFLOW  NETCASH_OPERATE  \
# 0         3639081000000          3489721000000     149360000000
# 1         3754346000000          3592871000000     161475000000
# 2         3832043000000          3715774000000     116269000000
# 3         3143608000000          2918434000000     225174000000
# 4         2511568000000          2343048000000     168520000000
#
#    TOTAL_INVEST_INFLOW  TOTAL_INVEST_OUTFLOW  NETCASH_INVEST  \
# 0         104645000000          265885000000   -161240000000
# 1         113746000000          269611000000   -155865000000
# 2         129359000000          224369000000    -95010000000
# 3          64837000000          210035000000   -145198000000
# 4         134355000000          237005000000   -102650000000
#
#    TOTAL_FINANCE_INFLOW  TOTAL_FINANCE_OUTFLOW  NETCASH_FINANCE    NETPROFIT
# 0          689198000000           708435000000     -19237000000  57547000000
# 1          701339000000           678607000000      22732000000  70046000000
# 2          569352000000           609051000000     -39699000000  76614000000
# 3          357593000000           415535000000     -57942000000  85030000000
# 4          563599000000           601109000000     -37510000000  42097000000

# %%
import akshare as ak

stock_cash_flow_sheet_by_yearly_em_df = ak.stock_cash_flow_sheet_by_yearly_em(symbol="SH600519")
#stock_cash_flow_sheet_by_yearly_em_df.T.to_excel("docs/cash_flow_em.xlsx")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
cash_flow_em = stock_cash_flow_sheet_by_yearly_em_df[["REPORT_DATE", "REPORT_TYPE", "CURRENCY",
    "TOTAL_OPERATE_INFLOW", "TOTAL_OPERATE_OUTFLOW", "NETCASH_OPERATE", 
    "TOTAL_INVEST_INFLOW", "TOTAL_INVEST_OUTFLOW", "NETCASH_INVEST", 
    "TOTAL_FINANCE_INFLOW", "TOTAL_FINANCE_OUTFLOW","NETCASH_FINANCE", "NETPROFIT"]]
cash_flow_em.head()
# Out:
#            REPORT_DATE REPORT_TYPE CURRENCY  TOTAL_OPERATE_INFLOW  \
# 0  2024-12-31 00:00:00          年报      CNY          2.000863e+11
# 1  2023-12-31 00:00:00          年报      CNY          1.682562e+11
# 2  2022-12-31 00:00:00          年报      CNY          1.378159e+11
# 3  2021-12-31 00:00:00          年报      CNY          1.316210e+11
# 4  2020-12-31 00:00:00          年报      CNY          1.135109e+11
#
#    TOTAL_OPERATE_OUTFLOW  NETCASH_OPERATE  TOTAL_INVEST_INFLOW  \
# 0           1.076226e+11     9.246369e+10         8.648630e+09
# 1           1.016629e+11     6.659325e+10         7.720217e+09
# 2           1.011173e+11     3.669860e+10         1.120691e+07
# 3           6.759231e+10     6.402868e+10         1.938686e+07
# 4           6.184178e+10     5.166907e+10         3.220777e+08
#
#    TOTAL_INVEST_OUTFLOW  NETCASH_INVEST  TOTAL_FINANCE_INFLOW  \
# 0          1.043383e+10   -1.785203e+09                   NaN
# 1          1.744463e+10   -9.724414e+09                   NaN
# 2          5.548033e+09   -5.536826e+09                   NaN
# 3          5.581833e+09   -5.562446e+09                   NaN
# 4          2.127305e+09   -1.805227e+09                   NaN
#
#    TOTAL_FINANCE_OUTFLOW  NETCASH_FINANCE     NETPROFIT
# 0           7.106751e+10    -7.106751e+10  8.933473e+10
# 1           5.888910e+10    -5.888910e+10  7.752148e+10
# 2           5.742453e+10    -5.742453e+10  6.537604e+10
# 3           2.656414e+10    -2.656414e+10  5.572053e+10
# 4           2.412754e+10    -2.412754e+10  4.952333e+10

# %% [markdown]
# #### IncomeStatement

# %%
from openbb import obb
income_obj = obb.equity.fundamental.income(symbol="600028", provider="akshare")
income_df = get_df(income_obj)
income_df.head()
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   period_ending fiscal_period fiscal_year reported_currency  cost_of_revenue  \
# 0    2024-12-31            年报        None               CNY     3.021457e+12
# 1    2023-12-31            年报        None               CNY     3.138351e+12
# 2    2022-12-31            年报        None               CNY     3.232467e+12
# 3    2021-12-31            年报        None               CNY     2.628882e+12
# 4    2020-12-31            年报        None               CNY     2.081582e+12
#
#    total_operating_income  total_pre_tax_income  income_tax_expense  \
# 0            3.074562e+12          7.051300e+10        1.296600e+10
# 1            3.212215e+12          8.611600e+10        1.607000e+10
# 2            3.318168e+12          9.451500e+10        1.790100e+10
# 3            2.740884e+12          1.083480e+11        2.331800e+10
# 4            2.104724e+12          4.844100e+10        6.344000e+09
#
#    consolidated_net_income  basic_earnings_per_share  \
# 0             5.754700e+10                     0.415
# 1             7.004600e+10                     0.505
# 2             7.661400e+10                     0.555
# 3             8.503000e+10                     0.588
# 4             4.209700e+10                     0.275
#
#    diluted_earnings_per_share
# 0                       0.415
# 1                       0.505
# 2                       0.555
# 3                       0.588
# 4                       0.275

# %% [markdown]
# ##### 利润表-东财
#
# AKShare API:
# https://akshare.akfamily.xyz/data/stock/stock.html#id185
#
# 东财数据:
# https://emweb.securities.eastmoney.com/PC_HSF10/NewFinanceAnalysis/Index?type=web&code=sh600519#lrb-0

# %%
import akshare as ak

stock_profit_sheet_by_yearly_em_df = ak.stock_profit_sheet_by_yearly_em(symbol="SH600519")
# stock_profit_sheet_by_yearly_em_df.T.to_excel("docs/income_statement_em.xlsx")
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
income_statement_em = stock_profit_sheet_by_yearly_em_df[["REPORT_DATE", "REPORT_TYPE", "CURRENCY", "TOTAL_OPERATE_COST", "TOTAL_OPERATE_INCOME", "TOTAL_PROFIT", "INCOME_TAX", "NETPROFIT", "BASIC_EPS", "DILUTED_EPS"]]
income_statement_em.head()
# Out:
#            REPORT_DATE REPORT_TYPE CURRENCY  TOTAL_OPERATE_COST  \
# 0  2024-12-31 00:00:00          年报      CNY        5.452397e+10
# 1  2023-12-31 00:00:00          年报      CNY        4.696089e+10
# 2  2022-12-31 00:00:00          年报      CNY        3.974831e+10
# 3  2021-12-31 00:00:00          年报      CNY        3.477690e+10
# 4  2020-12-31 00:00:00          年报      CNY        3.130513e+10
#
#    TOTAL_OPERATE_INCOME  TOTAL_PROFIT    INCOME_TAX     NETPROFIT  BASIC_EPS  \
# 0          1.741441e+11  1.196386e+11  3.030385e+10  8.933473e+10      68.64
# 1          1.505603e+11  1.036626e+11  2.614108e+10  7.752148e+10      59.49
# 2          1.275540e+11  8.770149e+10  2.232545e+10  6.537604e+10      49.93
# 3          1.094643e+11  7.452803e+10  1.880750e+10  5.572053e+10      41.76
# 4          9.799324e+10  6.619694e+10  1.667361e+10  4.952333e+10      37.17
#
#    DILUTED_EPS
# 0        68.64
# 1        59.49
# 2        49.93
# 3        41.76
# 4        37.17

# %% [markdown]
# #### BalanceSheet

# %%
from openbb import obb
balance_obj = obb.equity.fundamental.balance(symbol="600028", provider="akshare")
balance_df = get_df(balance_obj)
balance_df.head()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   period_ending fiscal_period  fiscal_year    totalAssets      totalDebt  \
# 0    2024-12-31            年报         2024  2084771000000  1108478000000
# 1    2023-12-31            年报         2023  2026674000000  1068019000000
# 2    2022-12-31            年报         2022  1951121000000  1010664000000
# 3    2021-12-31            年报         2021  1889255000000   973214000000
# 4    2020-12-31            年报         2020  1738896000000   850176000000
#
#     totalEquity
# 0  976293000000
# 1  958655000000
# 2  940457000000
# 3  916041000000
# 4  888720000000

# %% [markdown]
# ##### 财务报表-新浪
#
# API:  https://akshare.akfamily.xyz/data/stock/stock.html#id180
#
# Data: https://vip.stock.finance.sina.com.cn/corp/go.php/vFD_FinanceSummary/stockid/600600/displaytype/4.phtml?source=fzb&qq-pf-to=pcqq.group

# %%
import akshare as ak

stock_financial_report_sina_df = ak.stock_financial_report_sina(stock="sh600600", symbol="资产负债表")
balance_sheet_sina = stock_financial_report_sina_df.T
#balance_sheet_sina.to_excel("docs/balance_sheet_sina_df.xlsx")

# %%
# 报告日, 资产总计(totalAssets), 负债合计(totalDebt), 所有者权益(或股东权益)合计 (totalEquity)
import pandas as pd
balance_sheet_df = stock_financial_report_sina_df[["报告日", "资产总计", "负债合计", "所有者权益(或股东权益)合计"]]
balance_sheet_df["报告日"] = pd.to_datetime(balance_sheet_df["报告日"], format="%Y%m%d", errors="coerce")
balance_sheet_df.head()
# Out:
# C:\Users\roger\AppData\Local\Temp\ipykernel_27876\3636249029.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balance_sheet_df["报告日"] = pd.to_datetime(balance_sheet_df["报告日"], format="%Y%m%d", errors="coerce")
#          报告日           资产总计           负债合计 所有者权益(或股东权益)合计
# 0 2025-03-31  51291152685.0  19733489350.0  31557663335.0
# 1 2024-12-31  51420385832.0  21560843821.0  29859542011.0
# 2 2024-09-30  50371239687.0  19698994899.0  30672244788.0
# 3 2024-06-30  52805909965.0  23590301039.0  29215608926.0
# 4 2024-03-31  50459434299.0  20614109997.0  29845324302.0

# %% [markdown]
# ##### 财务报表-东财
# https://emweb.securities.eastmoney.com/PC_HSF10/NewFinanceAnalysis/Index?type=web&code=sh600519#lrb-0

# %% [markdown]
# ###### A股

# %%
import akshare as ak

stock_balance_sheet_by_yearly_em_df = ak.stock_balance_sheet_by_yearly_em(symbol="SH600519")
balance_sheet_em = stock_balance_sheet_by_yearly_em_df.T
#balance_sheet_em.to_excel("docs/balance_sheet_em.xlsx")
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
balance_sheet_em = stock_balance_sheet_by_yearly_em_df[["REPORT_DATE", "REPORT_TYPE", "REPORT_DATE_NAME", "TOTAL_ASSETS", "TOTAL_LIABILITIES", "TOTAL_EQUITY"]]
balance_sheet_em['REPORT_DATE_NAME'] = balance_sheet_em['REPORT_DATE_NAME'].str.extract('(\d{4})')[0].astype(int)
balance_sheet_em.head()
# Out:
# C:\Users\Roger\AppData\Local\Temp\ipykernel_31836\1028356269.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balance_sheet_em['REPORT_DATE_NAME'] = balance_sheet_em['REPORT_DATE_NAME'].str.extract('(\d{4})')[0].astype(int)
#            REPORT_DATE REPORT_TYPE  REPORT_DATE_NAME  TOTAL_ASSETS  \
# 0  2024-12-31 00:00:00          年报              2024  2.989446e+11
# 1  2023-12-31 00:00:00          年报              2023  2.726997e+11
# 2  2022-12-31 00:00:00          年报              2022  2.545008e+11
# 3  2021-12-31 00:00:00          年报              2021  2.551682e+11
# 4  2020-12-31 00:00:00          年报              2020  2.133958e+11
#
#    TOTAL_LIABILITIES  TOTAL_EQUITY
# 0       5.693326e+10  2.420113e+11
# 1       4.904319e+10  2.236565e+11
# 2       4.956274e+10  2.049381e+11
# 3       5.821069e+10  1.969575e+11
# 4       4.567513e+10  1.677207e+11

# %% [markdown]
# ###### 港股

# %%
import akshare as ak

stock_financial_hk_report_em_df = ak.stock_financial_hk_report_em(stock="00700", symbol="资产负债表", indicator="年度")
#stock_financial_hk_report_em_df.T.to_excel("docs/balance_sheet_em_hk.xlsx")

# %%
balance_sheet_em_hk = stock_financial_hk_report_em_df[["STD_REPORT_DATE", "FISCAL_YEAR", "AMOUNT"]]
balance_sheet_em_hk.head()
# Out:
#        STD_REPORT_DATE FISCAL_YEAR        AMOUNT
# 0  2024-12-31 00:00:00       12-31  8.018500e+10
# 1  2024-12-31 00:00:00       12-31  8.010000e+08
# 2  2024-12-31 00:00:00       12-31  1.961270e+11
# 3  2024-12-31 00:00:00       12-31  2.311700e+10
# 4  2024-12-31 00:00:00       12-31  1.230200e+10

# %% [markdown]
# ##### 财务报表-同花顺
# https://akshare.akfamily.xyz/data/stock/stock.html#id191
# https://basic.10jqka.com.cn/000063/finance.html

# %%
# 财务报表-同花顺 资产负债表

import akshare as ak

stock_financial_debt_ths_df = ak.stock_financial_debt_ths(symbol="000063", indicator="按年度")
balance_sheet_ths=stock_financial_debt_ths_df.T

# %%
balance_sheet_ths.to_excel("balance_sheet_ths.xlsx")

# %% [markdown]
# #### AvailableIndices

# %%
import akshare as ak

index_stock_info_df = ak.index_stock_info()

# %%
index_stock_info_df["currency"] = "CNY"
index_stock_info_df
# Out:
#     index_code display_name publish_date currency
# 0       000001         上证指数   1991-07-15      CNY
# 1       000002         A股指数   1992-02-21      CNY
# 2       000003         B股指数   1992-02-21      CNY
# 3       000004         工业指数   1993-05-03      CNY
# 4       000005         商业指数   1993-05-03      CNY
# ..         ...          ...          ...      ...
# 720     399994   中证信息安全主题指数   2015-03-12      CNY
# 721     399995     中证基建工程指数   2015-03-12      CNY
# 722     399996     中证智能家居指数   2014-09-17      CNY
# 723     399997       中证白酒指数   2015-01-21      CNY
# 724     399998       中证煤炭指数   2015-02-13      CNY
#
# [725 rows x 4 columns]

# %%
from openbb import obb
indx = obb.index.available(provider="akshare")
indx.results[0]
# Out:
# AKShareAvailableIndicesData(name=上证指数, currency=CNY, publish_date=1991-07-15, symbol=000001)

# %%
from openbb import obb
indx = obb.index.available(provider="yfinance")
indx.results[0]
# Out:
# YFinanceAvailableIndicesData(name=S&P 500 Index, currency=None, code=sp500, symbol=^GSPC)

# %%
fmp_indx  = obb.index.available(provider="fmp")

# %%
fmp_indx.results[0]
# Out:
# FMPAvailableIndicesData(name=S&P/TSX Capped Industrials Index, currency=CAD, stock_exchange=Toronto Stock Exchange, exchange_short_name=INDEX, symbol=^TTIN)

# %% [markdown]
# #### historical_dividends

# %% [markdown]
# ##### Helpers
# - `get_a_dividends`
# - `get_hk_dividends`

# %%
import logging
from openbb_akshare.utils.tools import setup_logger

setup_logger()
logger = logging.getLogger(__name__)

# %%
from openbb_akshare.utils.helpers import get_a_dividends, get_hk_dividends
div = get_a_dividends(symbol="000002")
# Out:
# c:\src\tmp\akshare\openbb_akshare\utils\helpers.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker['amount'] = div_df['分红方案说明'].apply(
# c:\src\tmp\akshare\openbb_akshare\utils\helpers.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker.rename(columns={'实施公告日': "report_date",

# %%
from openbb_akshare.utils.helpers import get_hk_dividends
div_hk = get_hk_dividends(symbol="02880")
# Out:
# f:\src\tmp\akshare\openbb_akshare\utils\helpers.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker['amount'] = div_df['方案'].apply(
# f:\src\tmp\akshare\openbb_akshare\utils\helpers.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker.rename(columns={'公告日期': "report_date",

# %% [markdown]
# ##### 分红情况-同花顺[](https://akshare.akfamily.xyz/data/stock/stock.html#id157 "Link to this heading")
#
# 接口: stock_fhps_detail_ths
#
# 目标地址: https://basic.10jqka.com.cn/new/603444/bonus.html
#
# 描述: 同花顺-分红情况

# %%
import akshare as ak

stock_fhps_detail_ths_df = ak.stock_fhps_detail_ths(symbol="600325")

# %%
stock_fhps_detail_ths_df.dropna(inplace=True)
stock_fhps_detail_ths_df.head()
# Out:
#       报告期       董事会日期  股东大会预案公告日期       实施公告日         分红方案说明     A股股权登记日  \
# 1  2004年报  2005-01-22  2005-02-24  2005-04-12      10派1元(含税)  2005-04-15
# 2  2005中报  2005-08-30  2005-10-10  2005-10-22         10转增3股  2005-10-27
# 3  2005年报  2006-02-18  2006-03-21  2006-04-01      10派1元(含税)  2006-04-06
# 7  2007年报  2008-01-23  2008-02-14  2008-02-21  10转10股派1元(含税)  2008-02-26
# 9  2008年报  2009-01-23  2009-02-13  2009-03-26    10派1.1元(含税)  2009-04-01
#
#       A股除权除息日      分红总额  方案进度   股利支付率  税前分红率
# 1  2005-04-18  2000.00万  实施方案  22.22%  1.43%
# 2  2005-10-28        --  实施方案      --     --
# 3  2006-04-07  2600.00万  实施方案  16.39%  1.14%
# 7  2008-02-27  3159.58万  实施方案    8.2%  0.23%
# 9  2009-04-02  8987.50万  实施方案   12.5%  0.66%

# %% [markdown]
# ##### 分红配送详情-港股-同花顺[](https://akshare.akfamily.xyz/data/stock/stock.html#id158 "Link to this heading")
#
# 接口: stock_hk_fhpx_detail_ths
#
# 目标地址: https://stockpage.10jqka.com.cn/HK0700/bonus/
#
# 描述: 同花顺-港股-分红派息

# %%
import akshare as ak

stock_hk_fhpx_detail_ths_df = ak.stock_hk_fhpx_detail_ths(symbol="2880")

# %%
stock_hk_fhpx_detail_ths_df.dropna(inplace=True)
stock_hk_fhpx_detail_ths_df.head()
# Out:
#          公告日期            方案         除净日         派息日  过户日期起止日-起始  过户日期起止日-截止  \
# 1  2007-06-13   每股0.06122港元  2007-05-10  2007-06-29  2007-05-12  2007-05-17
# 3  2008-06-18   每股0.09051港元  2008-05-15  2008-07-16  2008-05-19  2008-05-23
# 5  2009-06-19   每股0.10207港元  2009-05-18  2009-07-31  2009-05-20  2009-05-25
# 7  2010-06-18    每股人民币0.25元  2010-05-17  2010-07-31  2010-05-19  2010-06-18
# 9  2011-07-20  每股0.060221港元  2011-05-23  2011-08-19  2011-05-25  2011-06-24
#
#    类型    进度 以股代息
# 1  年报  实施完成    否
# 3  年报  实施完成    否
# 5  年报  实施完成    否
# 7  年报  实施完成    否
# 9  年报  实施完成    否

# %% [markdown]
# ##### obb.equity.fundamental.dividends

# %%
from openbb import obb
from openbb_akshare.utils.tools import setup_logger
setup_logger()

# %%
dividends = obb.equity.fundamental.dividends(symbol='600325', provider='akshare')
dividends.results[0]
# Out:
# 2025-07-03 16:44:18,582 - openbb_akshare.models.historical_dividends - INFO - Fetched historical dividends:
# [{'report_date': datetime.date(2005, 4, 12), 'description': '10派1元(含税)', 'record_date': datetime.date(2005, 4, 15), 'ex_dividend_date': datetime.date(2005, 4, 18), 'amount': 0.1}, {'report_date': datetime.date(2005, 10, 22), 'description': '10转增3股', 'record_date': datetime.date(2005, 10, 27), 'ex_dividend_date': datetime.date(2005, 10, 28), 'amount': 0.0}, {'report_date': datetime.date(2006, 4, 1), 'description': '10派1元(含税)', 'record_date': datetime.date(2006, 4, 6), 'ex_dividend_date': datetime.date(2006, 4, 7), 'amount': 0.1}, {'report_date': datetime.date(2008, 2, 21), 'description': '10转10股派1元(含税)', 'record_date': datetime.date(2008, 2, 26), 'ex_dividend_date': datetime.date(2008, 2, 27), 'amount': 0.1}, {'report_date': datetime.date(2009, 3, 26), 'description': '10派1.1元(含税)', 'record_date': datetime.date(2009, 4, 1), 'ex_dividend_date': datetime.date(2009, 4, 2), 'amount': 0.11}, {'report_date': datetime.date(2010, 6, 9), 'description': '10派1元(含税)', 'record_date': datetime.date(2010, 6, 17), 'ex_dividend_date': datetime.date(2010, 6, 18), 'amount': 0.1}, {'report_date': datetime.date(2011, 5, 27), 'description': '10派1元(含税)', 'record_date': datetime.date(2011, 6, 1), 'ex_dividend_date': datetime.date(2011, 6, 2), 'amount': 0.1}, {'report_date': datetime.date(2012, 5, 15), 'description': '10派1元(含税)', 'record_date': datetime.date(2012, 5, 21), 'ex_dividend_date': datetime.date(2012, 5, 22), 'amount': 0.1}, {'report_date': datetime.date(2013, 6, 26), 'description': '10派1.00元(含税)', 'record_date': datetime.date(2013, 7, 1), 'ex_dividend_date': datetime.date(2013, 7, 2), 'amount': 0.1}, {'report_date': datetime.date(2014, 6, 23), 'description': '10派2.0元(含税)', 'record_date': datetime.date(2014, 6, 27), 'ex_dividend_date': datetime.date(2014, 6, 30), 'amount': 0.2}, {'report_date': datetime.date(2015, 5, 5), 'description': '10派1元(含税)', 'record_date': datetime.date(2015, 5, 8), 'ex_dividend_date': datetime.date(2015, 5, 11), 'amount': 0.1}, {'report_date': datetime.date(2016, 6, 16), 'description': '10派1.50元(含税)', 'record_date': datetime.date(2016, 6, 21), 'ex_dividend_date': datetime.date(2016, 6, 22), 'amount': 0.15}, {'report_date': datetime.date(2017, 6, 2), 'description': '10转8股派8元(含税)', 'record_date': datetime.date(2017, 6, 7), 'ex_dividend_date': datetime.date(2017, 6, 8), 'amount': 0.8}, {'report_date': datetime.date(2018, 7, 3), 'description': '10派3元(含税)', 'record_date': datetime.date(2018, 7, 6), 'ex_dividend_date': datetime.date(2018, 7, 9), 'amount': 0.3}, {'report_date': datetime.date(2019, 6, 28), 'description': '10派1.5元(含税)', 'record_date': datetime.date(2019, 7, 4), 'ex_dividend_date': datetime.date(2019, 7, 5), 'amount': 0.15}, {'report_date': datetime.date(2019, 10, 31), 'description': '10派2元(含税)', 'record_date': datetime.date(2019, 11, 6), 'ex_dividend_date': datetime.date(2019, 11, 7), 'amount': 0.2}, {'report_date': datetime.date(2020, 7, 2), 'description': '10派4元(含税)', 'record_date': datetime.date(2020, 7, 7), 'ex_dividend_date': datetime.date(2020, 7, 8), 'amount': 0.4}, {'report_date': datetime.date(2021, 6, 29), 'description': '10派4.5元(含税)', 'record_date': datetime.date(2021, 7, 2), 'ex_dividend_date': datetime.date(2021, 7, 5), 'amount': 0.45}, {'report_date': datetime.date(2022, 5, 12), 'description': '10派4.6元(含税)', 'record_date': datetime.date(2022, 5, 19), 'ex_dividend_date': datetime.date(2022, 5, 20), 'amount': 0.46}, {'report_date': datetime.date(2023, 4, 21), 'description': '10派3.7元(含税)', 'record_date': datetime.date(2023, 4, 27), 'ex_dividend_date': datetime.date(2023, 4, 28), 'amount': 0.37}, {'report_date': datetime.date(2024, 7, 1), 'description': '10派3.7元(含税)', 'record_date': datetime.date(2024, 7, 4), 'ex_dividend_date': datetime.date(2024, 7, 5), 'amount': 0.37}, {'report_date': datetime.date(2025, 5, 20), 'description': '10派1.04元(含税)', 'record_date': datetime.date(2025, 5, 23), 'ex_dividend_date': datetime.date(2025, 5, 26), 'amount': 0.104}]
# 2025-07-03 16:44:18,652 - openbb_akshare.models.historical_dividends - INFO - Transformed historical dividends completed.
# AKShareHistoricalDividendsData(ex_dividend_date=2005-04-18, amount=0.1, reported_date=None, description=10派1元(含税), record_date=2005-04-15, declaration_date=None, report_date=2005-04-12)

# %%
from openbb import obb
dividends = obb.equity.fundamental.dividends(symbol='AAPL', provider='fmp')
dividends.results[0]
# Out:
# FMPHistoricalDividendsData(ex_dividend_date=2025-05-12, amount=0.26, label=May 12, 25, adj_dividend=0.26, record_date=2025-05-12, payment_date=2025-05-15, declaration_date=2025-05-01)

# %%
yf_dividends = obb.equity.fundamental.dividends(symbol='AAPL', provider='yfinance')
yf_dividends.results[0]
# Out:
# YFinanceHistoricalDividendsData(ex_dividend_date=1987-05-11, amount=0.000536)

# %%
import akshare as ak

stock_fhps_detail_em_df = ak.stock_fhps_detail_em(symbol="600325")
stock_fhps_detail_em_df.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#           报告期      业绩披露日期  送转股份-送转总比例  送转股份-送股比例  送转股份-转股比例  现金分红-现金分红比例  \
# 0  2004-12-31  2005-01-22         0.0        0.0        0.0          1.0
# 1  2005-06-30  2005-08-30         3.0        0.0        3.0          NaN
# 2  2005-12-31  2006-02-18         0.0        0.0        0.0          1.0
# 3  2007-12-31  2008-01-23        10.0        0.0       10.0          1.0
# 4  2008-12-31  2009-01-23         0.0        0.0        0.0          1.1
#
#                  现金分红-现金分红比例描述  现金分红-股息率  每股收益  每股净资产     每股公积金   每股未分配利润  \
# 0        10派1.00元(含税,扣税后0.80元)  0.014327  0.45  4.948  2.069137  1.242755
# 1                      10转3.00       NaN  0.35  5.202  2.069137  1.596814
# 2        10派1.00元(含税,扣税后0.90元)  0.011364  0.61  4.220  1.360874  1.267908
# 3  10转10.00派1.00元(含税,扣税后0.90元)  0.002350  1.22  6.230  2.266939  2.444449
# 4        10派1.10元(含税,扣税后0.99元)  0.006575  0.88  5.510  3.186507  1.073908
#
#       净利润同比增长        总股本       预案公告日       股权登记日       除权除息日  方案进度      最新公告日期
# 0   52.515641  200000000         NaT  2005-04-15  2005-04-18  实施分配  2005-04-12
# 1  178.905414  200000000         NaT  2005-10-27  2005-10-28  实施分配  2005-10-22
# 2   50.144752  260000000         NaT  2006-04-06  2006-04-07  实施分配  2006-04-01
# 3  145.474112  315957539  2008-01-23  2008-02-26  2008-02-27  实施分配  2008-02-21
# 4   81.609495  817045620  2009-01-23  2009-04-01  2009-04-02  实施分配  2009-03-26

# %% [markdown]
# #### equity_historical

# %%
from openbb import obb
fmp_prices = obb.equity.price.historical(symbol='AAPL', start_date="2025-06-01", end_date="2025-06-10", provider="fmp")
fmp_prices.to_dataframe().head()
# Out:
#               open    high     low   close    volume      vwap  adj_close  \
# date
# 2025-06-02  200.28  202.13  200.12  201.70  35423300  201.0575     201.70
# 2025-06-03  201.35  203.77  200.96  203.27  46381600  202.3375     203.27
# 2025-06-04  202.91  206.24  202.10  202.82  43604000  203.5175     202.82
# 2025-06-05  203.50  204.75  200.15  200.63  55221235  202.2575     200.63
# 2025-06-06  203.00  205.70  202.05  203.92  46607700  203.6675     203.92
#
#             unadjusted_volume  change  change_percent
# date
# 2025-06-02         35423300.0    1.42        0.007090
# 2025-06-03         46381600.0    1.92        0.009536
# 2025-06-04         43604000.0   -0.09       -0.000444
# 2025-06-05         55221235.0   -2.87       -0.014100
# 2025-06-06         46607700.0    0.92        0.004532

# %%
from openbb import obb
prices = obb.equity.price.historical(symbol='600325', start_date="2025-06-01", end_date="2025-06-10", provider="akshare")
prices.to_dataframe().head()
# Out:
#             open  high   low  close  volume  change  change_percent  symbol  \
# date
# 2025-06-03  4.89  4.93  4.86   4.90  174653   -0.01           -0.20  600325
# 2025-06-04  4.90  4.93  4.88   4.91  163078    0.01            0.20  600325
# 2025-06-05  4.91  4.95  4.90   4.92  139729    0.01            0.20  600325
# 2025-06-06  4.92  4.94  4.90   4.90  140267   -0.02           -0.41  600325
# 2025-06-09  4.92  4.96  4.92   4.94  185245    0.04            0.82  600325
#
#                 amount
# date
# 2025-06-03  85467700.0
# 2025-06-04  80002345.0
# 2025-06-05  68740329.0
# 2025-06-06  68913964.0
# 2025-06-09  91521126.0

# %%
import akshare as ak

stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20250601", end_date='20250610', adjust="")
stock_zh_a_hist_df.head()
# Out:
#            日期    股票代码     开盘     收盘     最高     最低      成交量           成交额  \
# 0  2025-06-03  000001  11.54  11.81  11.91  11.53  2192480  2.580963e+09
# 1  2025-06-04  000001  11.82  11.84  11.88  11.78  1167960  1.383020e+09
# 2  2025-06-05  000001  11.88  11.67  11.91  11.66  1166803  1.369212e+09
# 3  2025-06-06  000001  11.70  11.70  11.79  11.68   682353  7.999000e+08
# 4  2025-06-09  000001  11.73  11.71  11.75  11.65   773255  9.050926e+08
#
#      振幅   涨跌幅   涨跌额   换手率
# 0  3.29  2.16  0.25  1.13
# 1  0.85  0.25  0.03  0.60
# 2  2.11 -1.44 -0.17  0.60
# 3  0.94  0.26  0.03  0.35
# 4  0.85  0.09  0.01  0.40

# %%
stock_zh_a_hist_df.rename(columns={"日期": "date", "股票代码": "symbol", "开盘": "open", "收盘": "close", "最高": "high", "最低": "low", "成交量": "volume", "成交额": "amount", "涨跌幅":"change_percent", "涨跌额": "change"}, inplace=True)

# %%
stock_zh_a_hist_df
# Out:
#          date  symbol   open  close   high    low   volume        amount  \
# 0  2025-06-03  000001  11.54  11.81  11.91  11.53  2192480  2.580963e+09
# 1  2025-06-04  000001  11.82  11.84  11.88  11.78  1167960  1.383020e+09
# 2  2025-06-05  000001  11.88  11.67  11.91  11.66  1166803  1.369212e+09
# 3  2025-06-06  000001  11.70  11.70  11.79  11.68   682353  7.999000e+08
# 4  2025-06-09  000001  11.73  11.71  11.75  11.65   773255  9.050926e+08
# 5  2025-06-10  000001  11.72  11.81  11.89  11.71  1428132  1.689019e+09
#
#      振幅  change_percent  change   换手率
# 0  3.29            2.16    0.25  1.13
# 1  0.85            0.25    0.03  0.60
# 2  2.11           -1.44   -0.17  0.60
# 3  0.94            0.26    0.03  0.35
# 4  0.85            0.09    0.01  0.40
# 5  1.54            0.85    0.10  0.74

# %%
data1 = stock_zh_a_hist_df.drop(columns=["振幅"])
data1
# Out:
#          date  symbol   open  close   high    low   volume        amount  \
# 0  2025-06-03  000001  11.54  11.81  11.91  11.53  2192480  2.580963e+09
# 1  2025-06-04  000001  11.82  11.84  11.88  11.78  1167960  1.383020e+09
# 2  2025-06-05  000001  11.88  11.67  11.91  11.66  1166803  1.369212e+09
# 3  2025-06-06  000001  11.70  11.70  11.79  11.68   682353  7.999000e+08
# 4  2025-06-09  000001  11.73  11.71  11.75  11.65   773255  9.050926e+08
# 5  2025-06-10  000001  11.72  11.81  11.89  11.71  1428132  1.689019e+09
#
#    change_percent  change   换手率
# 0            2.16    0.25  1.13
# 1            0.25    0.03  0.60
# 2           -1.44   -0.17  0.60
# 3            0.26    0.03  0.35
# 4            0.09    0.01  0.40
# 5            0.85    0.10  0.74

# %%
from openbb_akshare.utils.helpers import ak_download
df = ak_download(symbol="000002", start_date="2025-06-01", end_date="2025-06-10", period="daily", adjust="")

# %%
df
# Out:
#          date  symbol  open  close  high   low   volume        amount    振幅  \
# 0  2025-06-03  000002  6.58   6.58  6.60  6.54   646833  4.249952e+08  0.90
# 1  2025-06-04  000002  6.59   6.62  6.64  6.57   506252  3.343369e+08  1.06
# 2  2025-06-05  000002  6.61   6.64  6.66  6.59   511213  3.387872e+08  1.06
# 3  2025-06-06  000002  6.64   6.60  6.66  6.59   452611  2.993021e+08  1.05
# 4  2025-06-09  000002  6.60   6.62  6.64  6.58   443997  2.937162e+08  0.91
# 5  2025-06-10  000002  6.63   6.60  6.73  6.56  1041358  6.914206e+08  2.57
#
#    change_percent  change   换手率
# 0           -0.90   -0.06  0.67
# 1            0.61    0.04  0.52
# 2            0.30    0.02  0.53
# 3           -0.60   -0.04  0.47
# 4            0.30    0.02  0.46
# 5           -0.30   -0.02  1.07

# %% [markdown]
# #### equity_quote
#
# ##### 实时行情数据-雪球[](https://akshare.akfamily.xyz/data/stock/stock.html#id21 "Link to this heading")
#
# 接口: stock_individual_spot_xq
#
# 目标地址: https://xueqiu.com/S/SH513520
#
# 描述: 雪球-行情中心-个股
#
# 限量: 单次获取指定 symbol 的最新行情数据

# %%
import akshare as ak

stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em()
# Out:
#   0%|          | 0/57 [00:00<?, ?it/s]

# %%
#stock_zh_a_spot_em_df.T.to_excel("../docs/stock_zh_a_spot_em.xlsx")
stock_quotes = stock_zh_a_spot_em_df[["代码", "名称", "最新价", "今开", "最高", "最低", "涨跌幅", "涨跌额", "成交量", "昨收"]]
stock_quotes.head()
# Out:
#        代码     名称     最新价      今开      最高      最低    涨跌幅    涨跌额       成交量  \
# 0  839680  *ST广道    5.87    4.20    5.87    4.18  29.87   1.35  196287.0
# 1  835305  *ST云创   16.33   12.91   17.15   12.91  22.78   3.03  242688.0
# 2  300436    广生堂   51.34   45.00   51.34   44.01  20.01   8.56  356788.0
# 3  688068   热景生物  194.81  169.81  194.81  169.81  20.00  32.47   52638.0
# 4  301389   隆扬电子   31.92   26.62   31.92   26.50  20.00   5.32  358897.0
#
#        昨收
# 0    4.52
# 1   13.30
# 2   42.78
# 3  162.34
# 4   26.60

# %%
from openbb import obb
data = obb.equity.price.quote(symbol='AAPL', provider='fmp')
data.results
# Out:
# [FMPEquityQuoteData(symbol=AAPL, asset_type=None, name=Apple Inc., exchange=NASDAQ, bid=None, bid_size=None, bid_exchange=None, ask=None, ask_size=None, ask_exchange=None, quote_conditions=None, quote_indicators=None, sales_conditions=None, sequence_number=None, market_center=None, participant_timestamp=None, trf_timestamp=None, sip_timestamp=None, last_price=213.55, last_tick=None, last_size=None, last_timestamp=2025-07-03 20:00:00+00:00, open=212.145, high=214.65, low=211.8101, close=None, volume=34955836, exchange_volume=None, prev_close=212.44, change=1.11, change_percent=0.005225, year_high=260.1, year_low=169.21, price_avg50=203.4426, price_avg200=223.1329, avg_volume=63501154, market_cap=3189540090000.0, shares_outstanding=14935800000, eps=7.09, pe=30.12, earnings_announcement=2025-07-30 10:59:00+00:00)]

# %%
from openbb_akshare.utils.tools import normalize_symbol
symbol = " 600325 "
symbol_b, symbol_f, market = normalize_symbol(symbol)
print(symbol_b, symbol_f, market)
# Out:
# 600325 600325.SH SH

# %%
from openbb import obb

ak_data = obb.equity.price.quote("871263,000002,000333,601006,601288,00300", provider='akshare')
ak_data.to_dataframe().head()
# Out:
#    symbol   name  last_price   open   high    low     volume  prev_close  \
# 0  871263   莱赛激光       22.51  22.37  22.66  22.22    20155.0       22.26
# 1  000002  万  科Ａ        6.56   6.51   6.58   6.47   820428.0        6.52
# 2  000333   美的集团       72.19  72.55  72.70  72.07   194682.0       72.55
# 3  601006   大秦铁路        6.64   6.65   6.65   6.60   438750.0        6.64
# 4  601288   农业银行        6.11   6.08   6.12   6.04  2513133.0        6.08
#
#    change  change_percent
# 0    0.25            1.12
# 1    0.04            0.61
# 2   -0.36           -0.50
# 3    0.00            0.00
# 4    0.03            0.49

# %% [markdown]
# #### equity_info

# %%
from openbb import obb
equity_info = obb.equity.profile(symbol="AAPL,EPAM", provider="fmp")
equity_info.to_dataframe()
# Out:
#   symbol                name         cik      cusip          isin  \
# 0   AAPL          Apple Inc.  0000320193  037833100  US0378331005
# 1   EPAM  EPAM Systems, Inc.  0001352010  29414B104  US29414B1044
#
#             stock_exchange                                   long_description  \
# 0     NASDAQ Global Select  Apple Inc. designs, manufactures, and markets ...
# 1  New York Stock Exchange  EPAM Systems, Inc. provides digital platform e...
#
#                ceo            company_url business_phone_no  ... is_fund  \
# 0  Timothy D. Cook  https://www.apple.com    (408) 996-1010  ...   False
# 1   Arkadiy Dobkin   https://www.epam.com      267 759 9000  ...   False
#
#                                                image currency     market_cap  \
# 0  https://images.financialmodelingprep.com/symbo...      USD  3153544812000
# 1  https://images.financialmodelingprep.com/symbo...      USD    10295495171
#
#   last_price  year_high year_low volume_avg annualized_dividend_amount   beta
# 0     211.14      260.1   169.21   55613603                       1.01  1.211
# 1     181.73      269.0   138.15     777270                       0.00  1.718
#
# [2 rows x 32 columns]

# %%
from openbb import obb
equity_info = obb.equity.profile(symbol="600050", provider="akshare")
equity_info.to_dataframe()
# Out:
#       symbol                                         name short_description  \
# 0  600050.SH  China United Network Communications Limited        联网通信、算网数智。
#
#                                     long_description  ceo  \
# 0  中国联合网络通信股份有限公司的主营业务是联网通信、算网数智。公司的主要产品是电信服务。公司荣...  陈忠岳
#
#              company_url business_address mailing_address business_phone_no  \
# 0  www.chinaunicom-a.com  北京市西城区金融大街21号4楼   北京市西城区金融大街21号    86-10-66259179
#
#   hq_address_postal_code  ... first_stock_price_date     org_name_cn  \
# 0                 100033  ...             2002-10-08  中国联合网络通信股份有限公司
#
#   org_short_name_cn org_short_name_en    org_id established_date  \
# 0              中国联通      China Unicom  03130194       2001-12-30
#
#   actual_issue_vol     reg_asset issue_price currency
# 0       5000000000  3.126443e+10         2.3      CNY
#
# [1 rows x 24 columns]

# %%
import akshare as ak
stock_individual_basic_info_xq_df = ak.stock_individual_basic_info_xq(symbol="SH601127")
stock_individual_basic_info_xq_df
# Out:
#                             item  \
# 0                         org_id
# 1                    org_name_cn
# 2              org_short_name_cn
# 3                    org_name_en
# 4              org_short_name_en
# 5        main_operation_business
# 6                operating_scope
# 7                district_encode
# 8            org_cn_introduction
# 9           legal_representative
# 10               general_manager
# 11                     secretary
# 12              established_date
# 13                     reg_asset
# 14                     staff_num
# 15                     telephone
# 16                      postcode
# 17                           fax
# 18                         email
# 19                   org_website
# 20                reg_address_cn
# 21                reg_address_en
# 22             office_address_cn
# 23             office_address_en
# 24               currency_encode
# 25                      currency
# 26                   listed_date
# 27               provincial_name
# 28             actual_controller
# 29                   classi_name
# 30                   pre_name_cn
# 31                      chairman
# 32               executives_nums
# 33              actual_issue_vol
# 34                   issue_price
# 35             actual_rc_net_amt
# 36              pe_after_issuing
# 37  online_success_rate_of_issue
# 38            affiliate_industry
#
#                                                 value
# 0                                          T000071215
# 1                                         赛力斯集团股份有限公司
# 2                                                 赛力斯
# 3                                Seres Group Co.,Ltd.
# 4                                               SERES
# 5                          新能源汽车及核心三电等产品的研发、制造、销售及服务。
# 6   　　一般项目：制造、销售：汽车零部件、机动车辆零部件、普通机械、电器机械、电器、电子产品（不...
# 7                                              500106
# 8   赛力斯始创于1986年，是以新能源汽车为核心业务的技术科技型汽车企业。现有员工1.6万人，A...
# 9                                                 张正萍
# 10                                                张正萍
# 11                                                 申薇
# 12                                      1178812800000
# 13                                       1633366086.0
# 14                                              18838
# 15                                     86-23-65179666
# 16                                             401335
# 17                                     86-23-65179777
# 18                                    601127@seres.cn
# 19                                   www.seres.com.cn
# 20                                      重庆市沙坪坝区五云湖路7号
# 21                                               None
# 22                                      重庆市沙坪坝区五云湖路7号
# 23                                               None
# 24                                             019001
# 25                                                CNY
# 26                                      1465920000000
# 27                                                重庆市
# 28                                       张兴海 (13.07%)
# 29                                               民营企业
# 30                                     重庆小康工业集团股份有限公司
# 31                                                张正萍
# 32                                                 20
# 33                                        142500000.0
# 34                                               5.81
# 35                                        738451000.0
# 36                                              18.19
# 37                                           0.110176
# 38         {'ind_code': 'BK0025', 'ind_name': '汽车整车'}

# %%
import pandas as pd

timestamp_ms = 1209484800000
dt = pd.to_datetime(timestamp_ms, unit='ms')

print(dt)  # 输出: 2000-04-03 00:00:00
# Out:
# 2008-04-29 16:00:00

# %%
import akshare as ak
stock_individual_basic_info_hk_xq_df = ak.stock_individual_basic_info_hk_xq(symbol="00300")
stock_individual_basic_info_hk_xq_df
# Out:
#            item                                              value
# 0       comunic                                        200000125.0
# 1     comcnname                                         美的集团股份有限公司
# 2     comenname                        Midea Group Company Limited
# 3       incdate                                     955036800000.0
# 4        rgiofc                         中国广东省佛山市顺德区北滘镇美的大道6号美的总部大厦
# 5    hofclctmbu                         中国广东省佛山市顺德区北滘镇美的大道6号美的总部大厦
# 6      chairman                                                方洪波
# 7           mbu  主要从事制造及销售家用空调、中央空调、供暖及通风系统、厨房家电、冰箱、洗衣机、各类小家电、电...
# 8       comintr  我们是一家全球领先、技术驱动的智能家居和商业及工业解决方案供应商。我们的产品和服务涵盖针对消...
# 9     refccomty                                                1.0
# 10     numtissh                                        565955300.0
# 11         ispr                                               54.8
# 12         nrfd                                      30668000000.0
# 13  nation_name                                                 中国
# 14          tel                         0757-226077080757-23274957
# 15          fax                                      0757-26605456
# 16        email                                       IR@midea.com
# 17     web_site                               http://www.midea.com
# 18    lsdateipo                                    1726502400000.0
# 19   mainholder                                           美的控股有限公司

# %%
import pandas as pd
from datetime import datetime

from openbb_akshare.utils.fetch_equity_info import fetch_equity_info

equity_info = fetch_equity_info("01288")
equity_info["listed_date"] = pd.to_datetime(equity_info["listed_date"], unit='ms')
equity_info["established_date"] = pd.to_datetime(equity_info["established_date"], unit='ms')
equity_info
# Out:
#      symbol                         org_name_en  \
# 6  01288.HK  Agricultural Bank of China Limited
#
#                              main_operation_business  \
# 6  主要经营范围包括：人民币和外币存款、贷款、清算和结算、资产托管、基金管理、金融租赁、保险业务...
#
#                                  org_cn_introduction chairman  \
# 6  中国农业银行股份有限公司是一家中国的商业银行。该银行主要通过四大类业务运营。公司金融业务包括...       谷澍
#
#                                 org_website     reg_address_cn  \
# 6  http://www.abchina.comwww.abchina.com.cn  中国北京市东城区建国门内大街69号
#
#   office_address_cn                             telephone postcode  ...  \
# 6   北京市东城区建国门内大街69号  010-85109619852-28617995852-28617995     None  ...
#
#           listed_date   org_name_cn org_short_name_cn org_short_name_en  \
# 6 2010-07-15 16:00:00  中国农业银行股份有限公司              None              None
#
#         org_id    established_date actual_issue_vol reg_asset issue_price  \
# 6  200002159.0 1979-02-22 16:00:00     2.541176e+10       NaN         3.2
#
#   currency
# 6      HKD
#
# [1 rows x 24 columns]

# %% [markdown]
# #### company_news
# 使用东财接口如下：
# ```python
# import akshare as ak
# stock_news_em_df = ak.stock_news_em(symbol="300059")
# ```

# %%
from openbb import obb

messages = obb.news.company("000002", provider="akshare")

# %%
messages.to_dataframe().head()
# Out:
#                                           title  \
# date
# 2025-06-04 19:00:17        万科A：截至5月31日尚未出售A股库存股
# 2025-06-06 19:15:27     万科A：深铁集团拟向公司提供不超过30亿元借款
# 2025-06-06 19:16:24      万科A：深铁集团拟向公司提供不超30亿元借款
# 2025-06-10 19:10:14      万科A：6月10日出售2200万股A股库存股
# 2025-06-10 19:34:06  万科A首次出售2200万A股库存股，筹资1.46亿元
#
#                                                                   text  \
# date
# 2025-06-04 19:00:17  人民财讯6月4日电，万科A0000026月4日晚间公告，公司此前披露，将通过集中竞价交易方式...
# 2025-06-06 19:15:27  每经AI快讯，6月6日，万科A（000002.SZ）公告称，公司第一大股东深圳市地铁集团有限...
# 2025-06-06 19:16:24  人民财讯6月6日电，万科A0000026月6日晚间公告，公司第一大股东深圳市地铁集团有限公司...
# 2025-06-10 19:10:14  人民财讯6月10日电，万科A0000026月10日晚间公告，公司6月10日通过集中竞价交易方...
# 2025-06-10 19:34:06  万科A（000002/02202）发布公告，公司于2025年6月10日通过集中竞价交易方式首...
#
#                                                                    url  source
# date
# 2025-06-04 19:00:17  http://finance.eastmoney.com/a/202506043421933...    人民财讯
# 2025-06-06 19:15:27  http://finance.eastmoney.com/a/202506063424218...  每日经济新闻
# 2025-06-06 19:16:24  http://finance.eastmoney.com/a/202506063424219...    人民财讯
# 2025-06-10 19:10:14  http://finance.eastmoney.com/a/202506103426764...    人民财讯
# 2025-06-10 19:34:06  http://finance.eastmoney.com/a/202506103426778...     财中社
